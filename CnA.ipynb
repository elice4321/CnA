# %%
print('hello')
# Out:
# hello

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('C:/Users/sumit/Downloads/Mumbai_Train_final.csv')
df['Platforms']=df['Platforms'].fillna('NULL')
df
# Out:
#             Station Station Code            Line  \
# 0        Churchgate          CCG         Western
# 1      Marine Lines          MEL         Western
# 2       Charni Road          CYR         Western
# 3        Grant Road          GTR         Western
# 4    Mumbai Central         MMCT         Western
# ..              ...          ...             ...
# 197           Neral          NRL  Neral-Matheran
# 198       Jumapatti          JTT  Neral-Matheran
# 199       Waterpipe          WTP  Neral-Matheran
# 200      Aman Lodge         AMNA  Neral-Matheran
# 201        Matheran          MAE  Neral-Matheran
#
#     Distance From Previous of the Line Time taken From Previous of the Line  \
# 0                                 0 KM                                0 min
# 1                                 1 KM                                3 min
# 2                                 1 KM                                2 min
# ...

# %%
df.head(100)
# Out:
#            Station Station Code       Line Distance From Previous of the Line  \
# 0       Churchgate          CCG    Western                               0 KM
# 1     Marine Lines          MEL    Western                               1 KM
# 2      Charni Road          CYR    Western                               1 KM
# 3       Grant Road          GTR    Western                               1 KM
# 4   Mumbai Central         MMCT    Western                               1 KM
# ..             ...          ...        ...                                ...
# 95           Thane          TNA  Central 2                               2 KM
# 96           Kalva         KLVA  Central 2                               2 KM
# 97          Mumbra          MBQ  Central 2                               3 KM
# 98         Diva Jn         DIVA  Central 2                               3 KM
# 99           Kopar         KOPR  Central 2                               4 KM
#
# ...

# %%
Avg_FootFall=df['Footfall (lakhs)'].mean()
Avg_FootFall=int(Avg_FootFall)
Avg_FootFall
# Out:
# 2

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 1.5 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.0/8.1 MB 1.5 MB/s eta 0:00:05
#    ------- -------------------------------- 1.6/8.1 MB 1.8 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.1/8.1 MB 2.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.4/8.1 MB 1.9 MB/s eta 0:00:03
#    -------------- ------------------------- 2.9/8.1 MB 1.9 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.4/8.1 MB 2.0 MB/s eta 0:00:03
#    ------------------ --------------------- 3.7/8.1 MB 2.0 MB/s eta 0:00:03
#    -------------------- ------------------- 4.2/8.1 MB 2.0 MB/s eta 0:00:02
# ...

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Group by 'Line' and calculate the mean attraction popularity score
line_popularity = df.groupby('Line')['Attraction Popularity Score'].mean().reset_index()

# Plotting
plt.figure(figsize=(12, 6))
plt.bar(line_popularity['Line'], line_popularity['Attraction Popularity Score'], color='skyblue')
plt.title('Attraction Popularity by Line')
plt.xlabel('Line')
plt.ylabel('Attraction Popularity Score')
plt.xticks(rotation=45)
plt.show()

# %%
# Assuming your DataFrame is named 'df'
# Count the number of stations per line
line_distribution = df['Line'].value_counts()

# Plotting
plt.figure(figsize=(8, 8))
plt.pie(line_distribution, labels=line_distribution.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Distribution of Stations by Line')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
sns.set(style="whitegrid")

# Plotting
plt.figure(figsize=(12, 6))
sns.boxplot(x='Line', y='Footfall (lakhs)', data=df, palette='Set2')
plt.title('Box Plot of Footfall by Line')
plt.xlabel('Line')
plt.ylabel('Footfall (lakhs)')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_3600\1594961804.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Line', y='Footfall (lakhs)', data=df, palette='Set2')

# %%
# Assuming your DataFrame is named 'df'
# Plotting
plt.figure(figsize=(12, 6))
plt.hist(df['Footfall (lakhs)'], bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of Station Footfall')
plt.xlabel('Footfall (lakhs)')
plt.ylabel('Number of Stations')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
plt.figure(figsize=(15, 8))
plt.bar(df['Station'], df['Footfall (lakhs)'], color='skyblue')
plt.title('Footfall per Station')
plt.xlabel('Station')
plt.ylabel('Footfall (lakhs)')
plt.xticks(rotation=90)  # Rotate station names for better visibility
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
print(df.columns)
# Out:
# Index(['Station', 'Station Code', 'Line', 'Distance From Previous of the Line',
#        'Time taken From Previous of the Line', 'Platforms', 'Tracks',
#        'Year of Opening', 'Footfall (lakhs)', 'Attraction Popularity Score'],
#       dtype='object')

# %%
print(df.columns)
# Out:
# Index(['Station', 'Station Code', 'Line', 'Distance From Previous of the Line',
#        'Time taken From Previous of the Line', 'Platforms', 'Tracks',
#        'Year of Opening', 'Footfall (lakhs)', 'Attraction Popularity Score'],
#       dtype='object')

# %%
print(df.columns)
# Out:
# Index(['station', 'station code', 'line', 'distance from previous of the line',
#        'time taken from previous of the line', 'platforms', 'tracks',
#        'year of opening', 'footfall (lakhs)', 'attraction popularity score'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame creation (replace this with your actual DataFrame)
# df = pd.read_csv('your_data_file.csv')  # Uncomment this line to load your data

# Check the column names
print("Column names in the DataFrame:", df.columns)

# Clean column names by stripping spaces and converting to lowercase
df.columns = df.columns.str.strip()  # Remove leading/trailing spaces
df.columns = df.columns.str.lower()   # Convert to lowercase

# Grouping the data by station and summing the footfall
station_footfall = df.groupby('station')['footfall (lakhs)'].sum().reset_index()

# Plotting
plt.figure(figsize=(15, 8))
plt.bar(station_footfall['station'], station_footfall['footfall (lakhs)'], color='lightblue')
plt.title('Total Footfall by Station')
plt.xlabel('Station')
plt.ylabel('Total Footfall (lakhs)')
plt.xticks(rotation=90)  # Rotate station names for better visibility
plt.grid(axis='y', alpha=0.75)
plt.show()
# Out:
# Column names in the DataFrame: Index(['station', 'station code', 'line', 'distance from previous of the line',
#        'time taken from previous of the line', 'platforms', 'tracks',
#        'year of opening', 'footfall (lakhs)', 'attraction popularity score'],
#       dtype='object')

# %%
# Prepare the data for the scatter plot
x = df['Footfall (lakhs)']  # Footfall data
y = df['Attraction Popularity Score']  # Attraction popularity score

# Create the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='blue', alpha=0.6)

# Adding titles and labels
plt.title('Footfall vs. Attraction Popularity Score', fontsize=16)
plt.xlabel('Footfall (in lakhs)', fontsize=14)
plt.ylabel('Attraction Popularity Score', fontsize=14)

# Adding grid for better readability
plt.grid(True)

# Show the plot
plt.show()

# %%
# Group the data by Line and sum the footfall
footfall_by_line = df.groupby('Line')['Footfall (lakhs)'].sum().reset_index()

# Create the line graph
plt.figure(figsize=(10, 6))
plt.plot(footfall_by_line['Line'], footfall_by_line['Footfall (lakhs)'], marker='o', color='blue', linestyle='-', alpha=0.7)

# Adding titles and labels
plt.title('Total Footfall by Train Line', fontsize=16)
plt.xlabel('Train Line', fontsize=14)
plt.ylabel('Total Footfall (in lakhs)', fontsize=14)

# Adding grid for better readability
plt.grid(True)

# Show the plot
plt.tight_layout()  # Adjust layout to prevent clipping of tick-labels
plt.show()

# %%
x = df['Footfall (lakhs)']
y = df['Attraction Popularity Score']

# Plot
plt.figure(figsize=(10, 6))
sns.regplot(x=x, y=y, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.title('Footfall vs. Attraction Popularity Score')
plt.xlabel('Footfall (in lakhs)')
plt.ylabel('Attraction Popularity Score')
plt.grid(True)
plt.show()
